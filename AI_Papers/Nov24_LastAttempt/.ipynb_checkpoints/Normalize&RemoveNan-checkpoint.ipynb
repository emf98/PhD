# %% [markdown]
# ### Remove NaN values from ellipse arrays and across... all others

# %%
#relevant import statements
import numpy as np
import math
import xarray as xr 
import pickle 
import matplotlib.pyplot as plt

# %%
infile = open("./Updated_Diags/two_wind_1959.p", 'rb') 
wind10 = pickle.load(infile)
infile.close()

infile = open("./Updated_Diags/two_size_1959.p", 'rb') 
size10 = pickle.load(infile)
infile.close()

infile = open("./Updated_Diags/two_cenlat_1959.p", 'rb')
cenlat10 = pickle.load(infile)
infile.close()

infile = open("nao_vals.p", 'rb')
nao = pickle.load(infile)
infile.close()

# %%
#eddy-heat flux anonym MDTF at 100hPa 
infile = open("./Updated_Diags/1959ZMeddyheatflux.p", 'rb') 
ehf100 = pickle.load(infile)
infile.close()

# %%
wind10.shape
# Out:
# (64, 151)

# %%
#remove repeat year
wind10 = np.delete(wind10,[20],0)
cenlat10 = np.delete(cenlat10,[20],0)
size10 = np.delete(size10,[20],0)

# %%
print(ehf100.shape)
# Out:
# (63, 152)

# %%
ehf100 = np.delete(ehf100,[120],1)

# %%
wind10.shape
# Out:
# (63, 151)

# %%
nao = nao.reshape((63,151))

# %%
clt = (cenlat10 - np.nanmin(cenlat10)) / (np.nanmax(cenlat10) - np.nanmin(cenlat10))
clt
# Out:
# array([[0.83095838, 0.85423714, 0.92601577, ..., 0.44295357, 0.36381327,
#         0.51767794],
#        [0.65005464, 0.6726568 , 0.68991114, ...,        nan,        nan,
#                nan],
#        [0.81278903, 0.83960633, 0.8290732 , ..., 0.7841419 , 0.76926303,
#         0.76839545],
#        ...,
#        [0.84261051, 0.81845839, 0.7862664 , ..., 0.75197095, 0.8276287 ,
#         0.83880138],
#        [0.85283663, 0.88083618, 0.90769558, ..., 0.68044123, 0.67199729,
#         0.69254451],
#        [0.58376701, 0.5808097 , 0.59643056, ..., 0.25543149, 0.22101192,
#                nan]])

# %%
sz = (size10 - np.nanmin(size10)) / (np.nanmax(size10) - np.nanmin(size10))
sz
# Out:
# array([[0.3284407 , 0.32771532, 0.32456567, ..., 0.08803593, 0.07921398,
#         0.15214199],
#        [0.27242673, 0.29329646, 0.30903952, ...,        nan,        nan,
#                nan],
#        [0.27047556, 0.29132258, 0.29004615, ..., 0.29023576, 0.28487237,
#         0.2694268 ],
#        ...,
#        [0.42131478, 0.44225572, 0.46496747, ..., 0.28910142, 0.29076762,
#         0.2888527 ],
#        [0.36201344, 0.37388203, 0.39221327, ..., 0.34821804, 0.33829851,
#         0.31398548],
#        [0.33688843, 0.34249698, 0.34162674, ..., 0.0084822 , 0.00682974,
#                nan]])

# %%
wd = (wind10 - np.nanmin(wind10)) / (np.nanmax(wind10) - np.nanmin(wind10))
wd
# Out:
# array([[0.52742235, 0.54633708, 0.53140104, ..., 0.38105848, 0.37906713,
#         0.37315273],
#        [0.45706024, 0.46877864, 0.46504039, ...,        nan,        nan,
#                nan],
#        [0.47975236, 0.49673652, 0.50387939, ..., 0.52283543, 0.51480643,
#         0.50979458],
#        ...,
#        [0.54497417, 0.55324992, 0.56600555, ..., 0.56538653, 0.57164265,
#         0.56920457],
#        [0.57602831, 0.58118641, 0.58717874, ..., 0.56419368, 0.52495313,
#         0.53862825],
#        [0.49278477, 0.50539953, 0.49184677, ..., 0.22475956, 0.22930856,
#                nan]])

# %%
ehf = (ehf100 - np.nanmin(ehf100)) / (np.nanmax(ehf100) - np.nanmin(ehf100))
ehf
# Out:
# array([[0.1507435 , 0.13600638, 0.16037645, ..., 0.35261483, 0.33112447,
#         0.31318257],
#        [0.2057267 , 0.19204298, 0.18645677, ..., 0.28448141, 0.25416488,
#         0.15838759],
#        [0.15838759, 0.18248715, 0.17626411, ..., 0.20500331, 0.20295785,
#         0.20265615],
#        ...,
#        [0.23382297, 0.21782596, 0.23318419, ..., 0.27223935, 0.25155252,
#         0.25401345],
#        [0.17953776, 0.13997393, 0.11701807, ..., 0.29984567, 0.3064717 ,
#         0.22380824],
#        [0.22380824, 0.21965641, 0.19308443, ..., 0.65931398, 0.635501  ,
#         0.20767115]])

# %%
nao = (nao - np.nanmin(nao)) / (np.nanmax(nao) - np.nanmin(nao))
nao
# Out:
# array([[0.768711  , 0.67570613, 0.63689307, ..., 0.54700057, 0.49390723,
#         0.43751845],
#        [0.34341511, 0.33352876, 0.3284025 , ..., 0.54022659, 0.53290337,
#         0.51001832],
#        [0.41756268, 0.39797308, 0.39815615, ..., 0.42049197, 0.46644517,
#         0.51642613],
#        ...,
#        [0.58930364, 0.56544065, 0.49664901, ..., 0.46526417, 0.47207848,
#         0.42492202],
#        [0.68890445, 0.62470276, 0.59434016, ..., 0.63552764, 0.58763336,
#         0.57232452],
#        [0.30095688, 0.31227268, 0.3274789 , ..., 0.42999327, 0.37278819,
#         0.32175084]])

# %%
indices = np.isnan(wd)
for i in range(0,63):
    for j in range(0,151):
        if indices[i,j] != False:
            print(i)
            print(j)
            print("True")
            wd[i,j] = 0
            clt[i,j] = 0
            sz[i,j] = 0
            ehf[i,j] = 0
            nao[i,j] = 0
# Out:
# 1
# 141
# True
# 1
# 142
# True
# 1
# 143
# True
# 1
# 144
# True
# 1
# 145
# True
# 1
# 146
# True
# 1
# 147
# True
# 1
# 148
# True
# 1
# 149
# True
# 1
# 150
# True
# 4
# 141
# True
# 4
# 142
# True
# 4
# 143
# True
# 4
# 144
# True
# 4
# 145
# True
# 4
# 146
# True
# 4
# 147
# True
# 4
# 148
# True
# 4
# 149
# True
# 4
# 150
# True
# 11
# 142
# True
# 11
# 143
# True
# 11
# 144
# True
# 11
# 145
# True
# 11
# 146
# True
# 11
# 147
# True
# 11
# 148
# True
# 11
# 149
# True
# 11
# 150
# True
# 13
# 149
# True
# 13
# 150
# True
# 15
# 142
# True
# 15
# 143
# True
# 15
# 144
# True
# 15
# 145
# True
# 15
# 146
# True
# 15
# 147
# True
# 15
# 148
# True
# 15
# 149
# True
# 15
# 150
# True
# 19
# 148
# True
# 19
# 149
# True
# 19
# 150
# True
# 20
# 150
# True
# 23
# 143
# True
# 23
# 144
# True
# 23
# 145
# True
# 23
# 146
# True
# 23
# 147
# True
# 23
# 149
# True
# 23
# 150
# True
# 24
# 129
# True
# 24
# 130
# True
# 24
# 131
# True
# 24
# 132
# True
# 24
# 133
# True
# 24
# 134
# True
# 24
# 135
# True
# 24
# 136
# True
# 24
# 137
# True
# 24
# 138
# True
# 24
# 139
# True
# 24
# 140
# True
# 24
# 141
# True
# 24
# 142
# True
# 24
# 143
# True
# 24
# 144
# True
# 24
# 145
# True
# 24
# 146
# True
# 24
# 147
# True
# 24
# 148
# True
# 24
# 149
# True
# 24
# 150
# True
# 25
# 146
# True
# 25
# 147
# True
# 25
# 148
# True
# 25
# 149
# True
# 25
# 150
# True
# 26
# 141
# True
# 26
# 150
# True
# 27
# 112
# True
# 27
# 113
# True
# 27
# 114
# True
# 27
# 115
# True
# 27
# 116
# True
# 27
# 117
# True
# 28
# 136
# True
# 28
# 137
# True
# 28
# 139
# True
# 28
# 140
# True
# 28
# 141
# True
# 28
# 142
# True
# 28
# 143
# True
# 28
# 144
# True
# 28
# 145
# True
# 28
# 146
# True
# 28
# 147
# True
# 28
# 148
# True
# 28
# 149
# True
# 28
# 150
# True
# 29
# 121
# True
# 29
# 130
# True
# 29
# 131
# True
# 29
# 132
# True
# 29
# 133
# True
# 29
# 134
# True
# 29
# 135
# True
# 29
# 136
# True
# 29
# 137
# True
# 29
# 138
# True
# 29
# 139
# True
# 29
# 140
# True
# 29
# 141
# True
# 29
# 142
# True
# 29
# 143
# True
# 29
# 144
# True
# 29
# 145
# True
# 29
# 146
# True
# 29
# 147
# True
# 29
# 148
# True
# 29
# 149
# True
# 29
# 150
# True
# 32
# 145
# True
# 32
# 146
# True
# 39
# 124
# True
# 39
# 125
# True
# 39
# 126
# True
# 39
# 127
# True
# 39
# 128
# True
# 39
# 129
# True
# 39
# 130
# True
# 39
# 131
# True
# 39
# 132
# True
# 39
# 133
# True
# 39
# 134
# True
# 39
# 135
# True
# 39
# 136
# True
# 39
# 137
# True
# 39
# 138
# True
# 39
# 139
# True
# 39
# 140
# True
# 39
# 141
# True
# 39
# 142
# True
# 39
# 143
# True
# 39
# 144
# True
# 39
# 145
# True
# 39
# 146
# True
# 39
# 147
# True
# 39
# 148
# True
# 39
# 149
# True
# 39
# 150
# True
# 41
# 110
# True
# 41
# 111
# True
# 41
# 112
# True
# 41
# 113
# True
# 41
# 114
# True
# 41
# 115
# True
# 45
# 143
# True
# 45
# 144
# True
# 45
# 145
# True
# 45
# 146
# True
# 45
# 147
# True
# 45
# 148
# True
# 45
# 149
# True
# 45
# 150
# True
# 48
# 136
# True
# 48
# 137
# True
# 48
# 138
# True
# 48
# 139
# True
# 48
# 140
# True
# 48
# 141
# True
# 48
# 142
# True
# 48
# 143
# True
# 48
# 144
# True
# 48
# 145
# True
# 48
# 146
# True
# 48
# 147
# True
# 48
# 148
# True
# 48
# 149
# True
# 48
# 150
# True
# 49
# 91
# True
# 49
# 92
# True
# 49
# 98
# True
# 49
# 99
# True
# 49
# 100
# True
# 49
# 101
# True
# 49
# 102
# True
# 49
# 103
# True
# 49
# 104
# True
# 49
# 105
# True
# 49
# 106
# True
# 49
# 107
# True
# 49
# 108
# True
# 49
# 109
# True
# 49
# 110
# True
# 49
# 111
# True
# 49
# 112
# True
# 49
# 113
# True
# 49
# 114
# True
# 49
# 115
# True
# 49
# 116
# True
# 49
# 117
# True
# 49
# 118
# True
# 49
# 119
# True
# 49
# 120
# True
# 49
# 121
# True
# 56
# 136
# True
# 56
# 137
# True
# 56
# 138
# True
# 56
# 139
# True
# 56
# 140
# True
# 56
# 141
# True
# 56
# 142
# True
# 56
# 143
# True
# 56
# 144
# True
# 56
# 145
# True
# 56
# 146
# True
# 56
# 147
# True
# 56
# 148
# True
# 56
# 149
# True
# 56
# 150
# True
# 58
# 114
# True
# 58
# 150
# True
# 62
# 147
# True
# 62
# 150
# True

# %%
##export out NaN removed variables
pickle.dump(sz, open("1959size10_NaN.p", 'wb')) 
pickle.dump(clt, open("1959cenlat10_NaN.p", 'wb'))
pickle.dump(ehf, open("1959ehf100_NaN.p", 'wb')) 
pickle.dump(wd, open("1959wind10_NaN.p", 'wb'))
pickle.dump(nao, open("1959nao_NaN.p", 'wb'))
