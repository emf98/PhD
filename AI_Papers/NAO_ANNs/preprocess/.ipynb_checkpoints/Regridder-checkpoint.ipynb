# %%
import numpy as np
import xarray as xr
import pickle
import xesmf as xe
# Out:
# /knight/anaconda_jan21/envs/aug21/lib/python3.8/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
# Load quarterly degree data of gph and temperature
#infile = open("./500GPH/FULL500_ANOM_capgph1959.p", 'rb') 
infile = open("1959_NAOgph500_2div.p", 'rb') 
gph = pickle.load(infile)
infile.close()

# %%
##indices
infile = open("era5_latindex.p", 'rb') 
lats = pickle.load(infile)
infile.close()

infile = open("era5_lonindex.p", 'rb') 
lons = pickle.load(infile)
infile.close()

infile = open("era5_timeindex.p", 'rb') 
time = pickle.load(infile)
infile.close()

# %% [raw]
# infile = open("./Temp/FULLeur1000_tempANOMs.p", 'rb')
# temp = pickle.load(infile)
# infile.close()

# %% [raw]
# temp.shape

# %%
##save year index
year = [i for i in range(1959,2022)] #indicate years for data, needed for opening files

# %%
##save lat lon indices
gph_lats = lats[40:281]
gph_lons = lons[360:721]
#temp_lats = lats[60:121]
#temp_lons = lons [760:901]

# %%
##create array for gph ... 
g = xr.DataArray(data= gph, dims = ["year","day","lat","lon"],coords = dict(year = year,
                                                                                day = time,
                                                                                lat = gph_lats,
                                                                                lon = gph_lons))
g
# Out:
# <xarray.DataArray (year: 63, day: 152, lat: 241, lon: 361)>
# array([[[[5046.34938838, 5045.59123344, 5044.83467125, ...,
#           5118.29287717, 5119.80759429, 5120.56415647],
#          [5038.01764781, 5037.26108563, 5036.50293068, ...,
#           5114.50528797, 5115.26344292, 5116.77816004],
#          [5029.6875    , 5028.17278287, 5027.41622069, ...,
#           5110.71929154, 5112.23400866, 5112.99216361],
#          ...,
#          [5884.68558869, 5884.68558869, 5884.68558869, ...,
#           5851.36340469, 5852.12155963, 5852.12155963],
#          [5883.92743374, 5883.92743374, 5883.92743374, ...,
#           5854.39283894, 5854.39283894, 5854.39283894],
#          [5882.41271662, 5883.17087156, 5883.17087156, ...,
#           5856.66411825, 5856.66411825, 5857.42227319]],
#
#         [[5092.5442788 , 5092.5442788 , 5091.78612385, ...,
#           5037.26108563, 5038.01764781, 5038.77580275],
#          [5080.42654179, 5080.42654179, 5079.66997961, ...,
#           5040.29051988, 5041.04708206, 5041.04708206],
#          [5069.06695973, 5068.31039755, 5067.55383537, ...,
#           5042.56179918, 5043.31995413, 5043.31995413],
# ...
#          [5858.60251019, 5859.35270133, 5859.35270133, ...,
#           5842.86283129, 5842.86283129, 5842.11423293],
#          [5859.35270133, 5859.35270133, 5859.35270133, ...,
#           5844.36321356, 5844.36321356, 5844.36321356],
#          [5859.35270133, 5859.35270133, 5859.35270133, ...,
#           5845.86200306, 5845.86200306, 5845.86200306]],
#
#         [[5041.65073904, 5041.65073904, 5042.40093017, ...,
#           5266.49942661, 5266.49942661, 5267.24961774],
#          [5037.15437054, 5037.15437054, 5037.90296891, ...,
#           5270.24719674, 5270.99738787, 5270.99738787],
#          [5032.65640928, 5032.65640928, 5033.40660041, ...,
#           5273.99496687, 5274.745158  , 5274.745158  ],
#          ...,
#          [5872.84339959, 5872.84339959, 5873.59359072, ...,
#           5840.61544343, 5840.61544343, 5840.61544343],
#          [5872.84339959, 5872.84339959, 5873.59359072, ...,
#           5840.61544343, 5840.61544343, 5840.61544343],
#          [5872.84339959, 5872.84339959, 5873.59359072, ...,
#           5840.61544343, 5840.61544343, 5840.61544343]]]])
# Coordinates:
#   * year     (year) int64 1959 1960 1961 1962 1963 ... 2017 2018 2019 2020 2021
#   * day      (day) <U5 '11-01' '11-02' '11-03' ... '03-29' '03-30' '03-31'
#   * lat      (lat) float32 80.0 79.75 79.5 79.25 79.0 ... 20.75 20.5 20.25 20.0
#   * lon      (lon) float32 -90.0 -89.75 -89.5 -89.25 ... -0.75 -0.5 -0.25 0.0

# %%
##create array for temp ... 
t = xr.DataArray(data= temp, dims = ["year","day","lat","lon"],coords = dict(year = year,
                                                                                day = time,
                                                                                lat = temp_lats,
                                                                                lon = temp_lons))
t

# %%
# Create the target grid (single degree)
t_out = xr.Dataset({'year':(['year'], year[:]),
                    'day':(['day'], time[:]),
                    'lat': (['lat'], np.arange(75, 59, -1)),
                    'lon': (['lon'], np.arange(10, 46, 1))})

# %%
t_out

# %%
# Create the regridder
regridder = xe.Regridder(t, t_out, 'bilinear', periodic=True)

# %%
# Regrid the data
t_single_degree = regridder(t)
t_single_degree

# %%
g_out = xr.Dataset({'year':(['year'], year[:]),
                    'day':(['day'], time[:]),
                    'lat': (['lat'], np.arange(80, 19.5, -2.5)),
                    'lon': (['lon'], np.arange(-90, -0.5, 2.5))})

# %%
# Create the regridder
regridder = xe.Regridder(g, g_out, 'bilinear', periodic=True)
# Out:
# /knight/anaconda_jan21/envs/aug21/lib/python3.8/site-packages/xarray/core/dataarray.py:789: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   return key in self.data

# %%
# Regrid the data
g_single_degree = regridder(g)
g_single_degree
# Out:
# /knight/anaconda_jan21/envs/aug21/lib/python3.8/site-packages/xesmf/frontend.py:522: FutureWarning: ``output_sizes`` should be given in the ``dask_gufunc_kwargs`` parameter. It will be removed as direct parameter in a future version.
#   dr_out = xr.apply_ufunc(
# <xarray.DataArray (year: 63, day: 152, lat: 25, lon: 36)>
# array([[[[5046.34938838, 5038.77580275, 5031.96037207, ...,
#           5096.33027523, 5104.66042304, 5112.23400866],
#          [4957.74401121, 4945.62627421, 4935.02484709, ...,
#           5060.73681193, 5059.98024975, 5069.06695973],
#          [4924.42182722, 4912.30568298, 4900.94610092, ...,
#           5070.58167686, 5073.61111111, 5083.45597604],
#          ...,
#          [5905.13188073, 5904.37531855, 5902.86060143, ...,
#           5822.58537207, 5805.92507645, 5786.99190877],
#          [5891.50101937, 5895.2870158 , 5895.2870158 , ...,
#           5844.54797401, 5836.97438838, 5829.40239551],
#          [5882.41271662, 5883.92743374, 5884.68558869, ...,
#           5863.48114169, 5858.17883537, 5856.66411825]],
#
#         [[5092.5442788 , 5087.24356524, 5082.69941386, ...,
#           5036.50293068, 5034.23165138, 5034.23165138],
#          [4978.94845821, 4978.19189602, 4983.49260958, ...,
#           5041.805237  , 5041.04708206, 5041.04708206],
#          [4917.60639653, 4928.96597859, 4942.59843272, ...,
#           5041.805237  , 5041.805237  , 5047.10595056],
# ...
#          [5830.12232416, 5834.61869266, 5836.86767329, ...,
#           5785.15226809, 5782.15468909, 5780.65589959],
#          [5851.10856269, 5851.10856269, 5850.35837156, ...,
#           5818.13041539, 5820.37939602, 5821.12799439],
#          [5859.35270133, 5860.10129969, 5855.60493119, ...,
#           5848.10939093, 5849.60977319, 5847.36079256]],
#
#         [[5041.65073904, 5045.39850917, 5050.64506881, ...,
#           5259.75407747, 5262.75324924, 5265.0006371 ],
#          [4989.93533384, 4995.18189348, 5003.42603211, ...,
#           5292.73222477, 5297.9787844 , 5303.22534404],
#          [4935.22234964, 4938.21992864, 4943.46648828, ...,
#           5316.7160423 , 5324.96018094, 5332.4557212 ],
#          ...,
#          [5864.59926096, 5871.34461009, 5879.58874873, ...,
#           5855.60493119, 5849.60977319, 5846.61060143],
#          [5871.34461009, 5878.08995923, 5881.83772936, ...,
#           5845.86200306, 5842.11423293, 5842.11423293],
#          [5872.84339959, 5876.59116972, 5876.59116972, ...,
#           5841.36404179, 5841.36404179, 5839.86525229]]]])
# Coordinates:
#   * year     (year) int64 1959 1960 1961 1962 1963 ... 2017 2018 2019 2020 2021
#   * day      (day) <U5 '11-01' '11-02' '11-03' ... '03-29' '03-30' '03-31'
#   * lon      (lon) float64 -90.0 -87.5 -85.0 -82.5 ... -10.0 -7.5 -5.0 -2.5
#   * lat      (lat) float64 80.0 77.5 75.0 72.5 70.0 ... 30.0 27.5 25.0 22.5 20.0
# Attributes:
#     regrid_method:  bilinear

# %%
gph1 = g_single_degree.values
gph1.shape
# Out:
# (63, 152, 25, 36)

# %%
temp1 = t_single_degree.values
temp1.shape

# %%
##remove leap days now
gph1 = np.delete(gph1,[120],1)
#temp1 = np.delete(temp1,[120],1)

# %%
temp1.shape

# %%
pickle.dump(gph1, open("shift_gph500_NAO25deg.p", 'wb'))
#pickle.dump(temp1, open("eurtemp1000_singledeg.p", 'wb'))
