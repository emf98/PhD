# %% [markdown]
# #### This code is formatted to use ERA-5/ERA-I data for calculating ellipses and metrics of the ellipse during a set period of record.
#
# In this code is an example for calculating and saving the ellipse metrics in a very brute-force manner.
#
# Below are the relevant import statements, including `fitEllipse3_new` and `EllipseDef_NAME`, which are additional python files.

# %%
import datetime as dt
import numpy as np
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import cartopy.feature
from cartopy.util import add_cyclic_point
import cartopy.crs as ccrs
import xarray as xr
import math
import netCDF4
#from get_ellipse_metrics import get_emetrics_max_min
from fitEllipse3_new import fitEllipseContour
from fitEllipse3_new import point_inside_polygon
#from EllipseCalc import ellipse_calc
from geopy.distance import great_circle
from matplotlib.patches import Polygon
from matplotlib import cm #colormaps!
import copy
import os
import scipy.stats
import pickle

#os.environ['DISPLAY']=':0.0'

# %% [markdown]
# This code requires you to **indicate save locations** for your images of ellipses and **import ERA-5 or ERA-Interim data**. This code assumes the user has the data saved locally.
#
# Please look at these definition statements to modify how the data is called for your circumstance.

# %%
from EllipseDef_ERA5 import ERA5_one_ellipse_calc
from EllipseDef_ERA5 import ERA5_two_ellipse_calc

# %% [markdown]
# The main part of the code begins here.

# %%
home_dir = '/home11/grad/2020/ef935217/Research/Dissertation/ELLIPSE_PAPER/' # Define your home working directory
lev_list = [10,50] #Define your list of hPa levels
temp_lev = [850] #Define your temperature level in hPa, if needed
#contour_list = [31500,20000,23000]
contour_list = [30000,20000] #Define your list of contours relevant to hPa measures #20000 for 50
windlat = 60.0 #Define latitude for zonal-mean winds
#write_out = True #write the ellipse data to a text file, True or False

# %% [markdown]
# The next chunk of code may be relevant for defining empty arrays of elliptical metrics should you wish to export and use them.
#
# `43` refers to the number of years covered by the period of record (1979-2022) and `152` refers to the number of time indexes (daily, November through March).

# %%
ephi_ratio10 = np.empty((63,152))
ephi_ratio10[:] = np.nan
ephi_wind10 = np.empty((63,152))
ephi_wind10[:] = np.nan
ephi_cenlat10 = np.empty((63,152))
ephi_cenlat10[:] = np.nan
ephi_cenlon10 = np.empty((63,152))
ephi_cenlon10[:] = np.nan
ephi_size10 = np.empty((63,152))
ephi_size10[:] = np.nan
ephi10 = np.empty((63,152))
ephi10[:] = np.nan
number10 = np.empty((63,152))
number10[:] = np.nan


ephi_ratio50 = np.empty((63,152))
ephi_ratio50[:] = np.nan
ephi_wind50 = np.empty((63,152))
ephi_wind50[:] = np.nan
ephi_cenlat50 = np.empty((63,152))
ephi_cenlat50[:] = np.nan
ephi_cenlon50 = np.empty((63,152))
ephi_cenlon50[:] = np.nan
ephi_size50 = np.empty((63,152))
ephi_size50[:] = np.nan
ephi50 = np.empty((63,152))
ephi50[:] = np.nan
number50 = np.empty((63,152))
number50[:] = np.nan

# %% [markdown]
# These empty lists are where the data will be saved within the definition statements.

# %%
rat10 = []
wind10 = []
cenlat10 = []
cenlon10 = []
size10 = []
ep10 = []
numb10 =[]
    
rat50 = []
wind50 = []
cenlat50 = []
cenlon50 = []
size50 = []
ep50 = []
numb50 = []

# %%
#running for January 2019
test = ERA5_one_ellipse_calc(lev_list,contour_list,windlat,2019,1,31,
                       rat10,wind10,cenlat10,cenlon10,size10,ep10,numb10,
                       rat50,wind50,cenlat50,cenlon50,size50,ep50,numb50,)

# %%
#liste of years and months
years = [y for y in range(1959,2022,1)]
month = [11,12,1,2,3]

# %%
##loop, calculate, and save
for i in range(len(years)):
    for j in range(len(month)):
        ##LEAP YEAR INDICES within this first loop, so February has 29 days
        #the second loop is the same without the additional day
        if years[i] == 1959 or years[i] == 1963 or years[i] == 1967 or years[i] == 1971 or years[i] == 1975 or years[i] == 1979 or years[i] == 1983 or years[i] == 1987 or years[i] == 1991 or years[i] == 1995 or years[i] == 1999 or years[i] == 2003 or years[i] == 2007 or years[i] == 2011 or years[i] == 2015 or years[i] == 2019:
            print(years[i])
            if month[j] == 11:
                print(month[j])
                ##conduct calculation for one ellipse at the desired year/month and append empty lists from earlier
                calc = ERA5_one_ellipse_calc(lev_list,contour_list,windlat,years[i],month[j],30,
                       rat10,wind10,cenlat10,cenlon10,size10,ep10,numb10,
                       rat50,wind50,cenlat50,cenlon50,size50,ep50,numb50)
                #attach the values from this iteration to the empty corresponding cells in the array for each level
                ephi_ratio10[i,0:30] = rat10[:]
                ephi_wind10[i,0:30] = wind10[:]
                ephi_cenlat10[i,0:30] = cenlat10[:]
                ephi_cenlon10[i,0:30] = cenlon10[:]
                ephi_size10[i,0:30] = size10[:]
                ephi10[i,0:30] = ep10[:]
                number10[i,0:30] = numb10[:]
                
                ephi_ratio50[i,0:30] = rat50[:]
                ephi_wind50[i,0:30] = wind50[:]
                ephi_cenlat50[i,0:30] = cenlat50[:]
                ephi_cenlon50[i,0:30] = cenlon50[:]
                ephi_size50[i,0:30] = size50[:]
                ephi50[i,0:30] = ep50[:]
                number50[i,0:30] = numb50[:]
           ##repeat the process     
            if month[j] == 12:
                print(month[j])
                calc = ERA5_one_ellipse_calc(lev_list,contour_list,windlat,years[i],month[j],31,
                       rat10,wind10,cenlat10,cenlon10,size10,ep10,numb10,
                       rat50,wind50,cenlat50,cenlon50,size50,ep50,numb50)

                ephi_ratio10[i,30:61] = rat10[:]
                ephi_wind10[i,30:61] = wind10[:]
                ephi_cenlat10[i,30:61] = cenlat10[:]
                ephi_cenlon10[i,30:61] = cenlon10[:]
                ephi_size10[i,30:61] = size10[:]
                ephi10[i,30:61] = ep10[:]
                number10[i,30:61] = numb10[:]
                
                ephi_ratio50[i,30:61] = rat50[:]
                ephi_wind50[i,30:61] = wind50[:]
                ephi_cenlat50[i,30:61] = cenlat50[:]
                ephi_cenlon50[i,30:61] = cenlon50[:]
                ephi_size50[i,30:61] = size50[:]
                ephi50[i,30:61] = ep50[:]
                number50[i,30:61] = numb50[:]
            
            if month[j] == 1:
                print(month[j])
                calc = ERA5_one_ellipse_calc(lev_list,contour_list,windlat,years[i]+1,month[j],31,
                       rat10,wind10,cenlat10,cenlon10,size10,ep10,numb10,
                       rat50,wind50,cenlat50,cenlon50,size50,ep50,numb50)

                ephi_ratio10[i,61:92] = rat10[:]
                ephi_wind10[i,61:92] = wind10[:]
                ephi_cenlat10[i,61:92] = cenlat10[:]
                ephi_cenlon10[i,61:92] = cenlon10[:]
                ephi_size10[i,61:92] = size10[:]
                ephi10[i,61:92] = ep10[:]
                number10[i,61:92] = numb10[:]
                
                ephi_ratio50[i,61:92] = rat50[:]
                ephi_wind50[i,61:92] = wind50[:]
                ephi_cenlat50[i,61:92] = cenlat50[:]
                ephi_cenlon50[i,61:92] = cenlon50[:]
                ephi_size50[i,61:92] = size50[:]
                ephi50[i,61:92] = ep50[:]
                number50[i,61:92] = numb50[:]
            
            if month[j] == 2:
                print(month[j])
                calc = ERA5_one_ellipse_calc(lev_list,contour_list,windlat,years[i]+1,month[j],29,
                       rat10,wind10,cenlat10,cenlon10,size10,ep10,numb10,
                       rat50,wind50,cenlat50,cenlon50,size50,ep50,numb50)

                ephi_ratio10[i,92:121] = rat10[:]
                ephi_wind10[i,92:121] = wind10[:]
                ephi_cenlat10[i,92:121] = cenlat10[:]
                ephi_cenlon10[i,92:121] = cenlon10[:]
                ephi_size10[i,92:121] = size10[:]
                ephi10[i,92:121] = ep10[:]
                number10[i,92:121] = numb10[:]
                
                ephi_ratio50[i,92:121] = rat50[:]
                ephi_wind50[i,92:121] = wind50[:]
                ephi_cenlat50[i,92:121] = cenlat50[:]
                ephi_cenlon50[i,92:121] = cenlon50[:]
                ephi_size50[i,92:121] = size50[:]
                ephi50[i,92:121] = ep50[:]
                number50[i,92:121] = numb50[:]
            
            if month[j] == 3:
                print(month[j])
                calc = ERA5_one_ellipse_calc(lev_list,contour_list,windlat,years[i]+1,month[j],31,
                       rat10,wind10,cenlat10,cenlon10,size10,ep10,numb10,
                       rat50,wind50,cenlat50,cenlon50,size50,ep50,numb50)

                ephi_ratio10[i,121:] = rat10[:]
                ephi_wind10[i,121:] = wind10[:]
                ephi_cenlat10[i,121:] = cenlat10[:]
                ephi_cenlon10[i,121:] = cenlon10[:]
                ephi_size10[i,121:] = size10[:]
                ephi10[i,121:] = ep10[:]
                number10[i,121:] = numb10[:]
                
                ephi_ratio50[i,121:] = rat50[:]
                ephi_wind50[i,121:] = wind50[:]
                ephi_cenlat50[i,121:] = cenlat50[:]
                ephi_cenlon50[i,121:] = cenlon50[:]
                ephi_size50[i,121:] = size50[:]
                ephi50[i,121:] = ep50[:]
                number50[i,121:] = numb50[:]

        ##ALL OTHER YEARS.... the second loop
        else:
            print(years[i])
            if month[j] == 11:
                print(month[j])
                calc = ERA5_one_ellipse_calc(lev_list,contour_list,windlat,years[i],month[j],30,
                       rat10,wind10,cenlat10,cenlon10,size10,ep10,numb10,
                       rat50,wind50,cenlat50,cenlon50,size50,ep50,numb50)
                
                ephi_ratio10[i,0:30] = rat10[:]
                ephi_wind10[i,0:30] = wind10[:]
                ephi_cenlat10[i,0:30] = cenlat10[:]
                ephi_cenlon10[i,0:30] = cenlon10[:]
                ephi_size10[i,0:30] = size10[:]
                ephi10[i,0:30] = ep10[:]
                number10[i,0:30] = numb10[:]
                
                ephi_ratio50[i,0:30] = rat50[:]
                ephi_wind50[i,0:30] = wind50[:]
                ephi_cenlat50[i,0:30] = cenlat50[:]
                ephi_cenlon50[i,0:30] = cenlon50[:]
                ephi_size50[i,0:30] = size50[:]
                ephi50[i,0:30] = ep50[:]
                number50[i,0:30] = numb50[:]
                
            if month[j] == 12:
                print(month[j])
                calc = ERA5_one_ellipse_calc(lev_list,contour_list,windlat,years[i],month[j],31,
                       rat10,wind10,cenlat10,cenlon10,size10,ep10,numb10,
                       rat50,wind50,cenlat50,cenlon50,size50,ep50,numb50)

                ephi_ratio10[i,30:61] = rat10[:]
                ephi_wind10[i,30:61] = wind10[:]
                ephi_cenlat10[i,30:61] = cenlat10[:]
                ephi_cenlon10[i,30:61] = cenlon10[:]
                ephi_size10[i,30:61] = size10[:]
                ephi10[i,30:61] = ep10[:]
                number10[i,30:61] = numb10[:]
                
                ephi_ratio50[i,30:61] = rat50[:]
                ephi_wind50[i,30:61] = wind50[:]
                ephi_cenlat50[i,30:61] = cenlat50[:]
                ephi_cenlon50[i,30:61] = cenlon50[:]
                ephi_size50[i,30:61] = size50[:]
                ephi50[i,30:61] = ep50[:]
                number50[i,30:61] = numb50[:]
            
            if month[j] == 1:
                print(month[j])
                calc = ERA5_one_ellipse_calc(lev_list,contour_list,windlat,years[i]+1,month[j],31,
                       rat10,wind10,cenlat10,cenlon10,size10,ep10,numb10,
                       rat50,wind50,cenlat50,cenlon50,size50,ep50,numb50)

                ephi_ratio10[i,61:92] = rat10[:]
                ephi_wind10[i,61:92] = wind10[:]
                ephi_cenlat10[i,61:92] = cenlat10[:]
                ephi_cenlon10[i,61:92] = cenlon10[:]
                ephi_size10[i,61:92] = size10[:]
                ephi10[i,61:92] = ep10[:]
                number10[i,61:92] = numb10[:]
                
                ephi_ratio50[i,61:92] = rat50[:]
                ephi_wind50[i,61:92] = wind50[:]
                ephi_cenlat50[i,61:92] = cenlat50[:]
                ephi_cenlon50[i,61:92] = cenlon50[:]
                ephi_size50[i,61:92] = size50[:]
                ephi50[i,61:92] = ep50[:]
                number50[i,61:92] = numb50[:]
            
            if month[j] == 2:
                print(month[j])
                calc = ERA5_one_ellipse_calc(lev_list,contour_list,windlat,years[i]+1,month[j],28,
                       rat10,wind10,cenlat10,cenlon10,size10,ep10,numb10,
                       rat50,wind50,cenlat50,cenlon50,size50,ep50,numb50)

                ephi_ratio10[i,92:120] = rat10[:]
                ephi_wind10[i,92:120] = wind10[:]
                ephi_cenlat10[i,92:120] = cenlat10[:]
                ephi_cenlon10[i,92:120] = cenlon10[:]
                ephi_size10[i,92:120] = size10[:]
                ephi10[i,92:120] = ep10[:]
                number10[i,92:120] = numb10[:]
                
                ephi_ratio50[i,92:120] = rat50[:]
# 12
# Opening ERA5 data 10 and contour level 30000
# Opening ERA5 data 50 and contour level 20000
# 2004
# 1
# Opening ERA5 data 10 and contour level 30000
# Opening ERA5 data 50 and contour level 20000
# 2004
# 2
# Opening ERA5 data 10 and contour level 30000
# Opening ERA5 data 50 and contour level 20000
# 2004
# 3
# Opening ERA5 data 10 and contour level 30000
# Opening ERA5 data 50 and contour level 20000
# 2005
# 11
# Opening ERA5 data 10 and contour level 30000
# Opening ERA5 data 50 and contour level 20000
# 2005
# 12
# Opening ERA5 data 10 and contour level 30000
# Opening ERA5 data 50 and contour level 20000
# 2005
# 1
# Opening ERA5 data 10 and contour level 30000
# Opening ERA5 data 50 and contour level 20000
# 2005
# 2
# Opening ERA5 data 10 and contour level 30000
# Opening ERA5 data 50 and contour level 20000
# 2005
# 3
# Opening ERA5 data 10 and contour level 30000
# Opening ERA5 data 50 and contour level 20000
# 2006
# 11
# Opening ERA5 data 10 and contour level 30000
# Opening ERA5 data 50 and contour level 20000
# 2006
# 12
# Opening ERA5 data 10 and contour level 30000
# Opening ERA5 data 50 and contour level 20000
# 2006
# 1
# Opening ERA5 data 10 and contour level 30000
# Opening ERA5 data 50 and contour level 20000
# 2006
# 2
# Opening ERA5 data 10 and contour level 30000
# Opening ERA5 data 50 and contour level 20000
# 2006
# 3
# Opening ERA5 data 10 and contour level 30000
# Opening ERA5 data 50 and contour level 20000
# 2007
# 11
# Opening ERA5 data 10 and contour level 30000
# Opening ERA5 data 50 and contour level 20000
# 2007
# 12
# Opening ERA5 data 10 and contour level 30000
# Opening ERA5 data 50 and contour level 20000
# 2007
# 1
# Opening ERA5 data 10 and contour level 30000
# Opening ERA5 data 50 and contour level 20000
# 2007
# 2
# Opening ERA5 data 10 and contour level 30000
# Opening ERA5 data 50 and contour level 20000
# 2007
# 3
# Opening ERA5 data 10 and contour level 30000
# Opening ERA5 data 50 and contour level 20000
# 2008
# 11
# Opening ERA5 data 10 and contour level 30000
# Opening ERA5 data 50 and contour level 20000
# 2008
# 12
# Opening ERA5 data 10 and contour level 30000
# Opening ERA5 data 50 and contour level 20000
# 2008
# 1
# Opening ERA5 data 10 and contour level 30000
# Opening ERA5 data 50 and contour level 20000
# 2008
# 2
# Opening ERA5 data 10 and contour level 30000
# Opening ERA5 data 50 and contour level 20000
# 2008
# 3
# Opening ERA5 data 10 and contour level 30000
# Opening ERA5 data 50 and contour level 20000
# 2009
# 11
# Opening ERA5 data 10 and contour level 30000
# Opening ERA5 data 50 and contour level 20000
# 2009
# 12
# Opening ERA5 data 10 and contour level 30000
# Opening ERA5 data 50 and contour level 20000
# 2009
# 1
# Opening ERA5 data 10 and contour level 30000
# Opening ERA5 data 50 and contour level 20000
# 2009
# 2
# Opening ERA5 data 10 and contour level 30000
# Opening ERA5 data 50 and contour level 20000
# 2009
# 3
# Opening ERA5 data 10 and contour level 30000
# Opening ERA5 data 50 and contour level 20000
# 2010
# 11
# Opening ERA5 data 10 and contour level 30000
# Opening ERA5 data 50 and contour level 20000
# 2010
# 12
# Opening ERA5 data 10 and contour level 30000
# Opening ERA5 data 50 and contour level 20000
# 2010
# 1
# Opening ERA5 data 10 and contour level 30000
# Opening ERA5 data 50 and contour level 20000
# 2010
# 2
# Opening ERA5 data 10 and contour level 30000
# Opening ERA5 data 50 and contour level 20000
# 2010
# 3
# Opening ERA5 data 10 and contour level 30000
# Opening ERA5 data 50 and contour level 20000
# 2011
# 11
# Opening ERA5 data 10 and contour level 30000
# Opening ERA5 data 50 and contour level 20000
# 2011
# 12
# Opening ERA5 data 10 and contour level 30000
# Opening ERA5 data 50 and contour level 20000
# 2011
# 1
# Opening ERA5 data 10 and contour level 30000
# Opening ERA5 data 50 and contour level 20000
# 2011
# 2
# Opening ERA5 data 10 and contour level 30000
# Opening ERA5 data 50 and contour level 20000
# 2011
# 3
# Opening ERA5 data 10 and contour level 30000
# Opening ERA5 data 50 and contour level 20000
# 2012
# 11
# Opening ERA5 data 10 and contour level 30000
# Opening ERA5 data 50 and contour level 20000
# 2012
# 12
# Opening ERA5 data 10 and contour level 30000
# Opening ERA5 data 50 and contour level 20000
# 2012
# 1
# Opening ERA5 data 10 and contour level 30000
# Opening ERA5 data 50 and contour level 20000
# 2012
# 2
# Opening ERA5 data 10 and contour level 30000
# Opening ERA5 data 50 and contour level 20000
# 2012
# 3
# Opening ERA5 data 10 and contour level 30000
# Opening ERA5 data 50 and contour level 20000
# 2013
# 11
# Opening ERA5 data 10 and contour level 30000
# Opening ERA5 data 50 and contour level 20000
# 2013
# 12
# Opening ERA5 data 10 and contour level 30000
# Opening ERA5 data 50 and contour level 20000
# 2013
# 1
# Opening ERA5 data 10 and contour level 30000
# Opening ERA5 data 50 and contour level 20000
# 2013
# 2
# Opening ERA5 data 10 and contour level 30000
# Opening ERA5 data 50 and contour level 20000
# 2013
# 3
# Opening ERA5 data 10 and contour level 30000
# Opening ERA5 data 50 and contour level 20000
# 2014
# 11
# Opening ERA5 data 10 and contour level 30000
# Opening ERA5 data 50 and contour level 20000
# 2014
# 12
# Opening ERA5 data 10 and contour level 30000
# Opening ERA5 data 50 and contour level 20000
# 2014
# 1
# Opening ERA5 data 10 and contour level 30000
# Opening ERA5 data 50 and contour level 20000
# 2014
# 2
# Opening ERA5 data 10 and contour level 30000
# Opening ERA5 data 50 and contour level 20000
# 2014
# 3
# Opening ERA5 data 10 and contour level 30000
# Opening ERA5 data 50 and contour level 20000
# 2015
# 11
# Opening ERA5 data 10 and contour level 30000
# Opening ERA5 data 50 and contour level 20000
# 2015
# 12
# Opening ERA5 data 10 and contour level 30000
# Opening ERA5 data 50 and contour level 20000
# 2015
# 1
# Opening ERA5 data 10 and contour level 30000
# Opening ERA5 data 50 and contour level 20000
# 2015
# 2
# Opening ERA5 data 10 and contour level 30000
# Opening ERA5 data 50 and contour level 20000
# 2015
# 3
# Opening ERA5 data 10 and contour level 30000
# Opening ERA5 data 50 and contour level 20000
# 2016
# 11
# Opening ERA5 data 10 and contour level 30000
# Opening ERA5 data 50 and contour level 20000
# 2016
# 12
# Opening ERA5 data 10 and contour level 30000
# Opening ERA5 data 50 and contour level 20000
# 2016
# 1
# Opening ERA5 data 10 and contour level 30000
# Opening ERA5 data 50 and contour level 20000
# 2016
# 2
# Opening ERA5 data 10 and contour level 30000
# Opening ERA5 data 50 and contour level 20000
# 2016
# 3
# Opening ERA5 data 10 and contour level 30000
# Opening ERA5 data 50 and contour level 20000
# 2017
# 11
# Opening ERA5 data 10 and contour level 30000
# Opening ERA5 data 50 and contour level 20000
# 2017
# 12
# Opening ERA5 data 10 and contour level 30000
# Opening ERA5 data 50 and contour level 20000
# 2017
# 1
# Opening ERA5 data 10 and contour level 30000
# Opening ERA5 data 50 and contour level 20000
# 2017
# 2
# Opening ERA5 data 10 and contour level 30000
# Opening ERA5 data 50 and contour level 20000
# 2017
# 3
# Opening ERA5 data 10 and contour level 30000
# Opening ERA5 data 50 and contour level 20000
# 2018
# 11
# Opening ERA5 data 10 and contour level 30000
# Opening ERA5 data 50 and contour level 20000
# 2018
# 12
# Opening ERA5 data 10 and contour level 30000
# Opening ERA5 data 50 and contour level 20000
# 2018
# 1
# Opening ERA5 data 10 and contour level 30000
# Opening ERA5 data 50 and contour level 20000
# 2018
# 2
# Opening ERA5 data 10 and contour level 30000
# Opening ERA5 data 50 and contour level 20000
# 2018
# 3
# Opening ERA5 data 10 and contour level 30000
# Opening ERA5 data 50 and contour level 20000
# 2019
# 11
# Opening ERA5 data 10 and contour level 30000
# Opening ERA5 data 50 and contour level 20000
# 2019
# 12
# Opening ERA5 data 10 and contour level 30000
# Opening ERA5 data 50 and contour level 20000
# 2019
# 1
# Opening ERA5 data 10 and contour level 30000
# Opening ERA5 data 50 and contour level 20000
# 2019
# 2
# Opening ERA5 data 10 and contour level 30000
# Opening ERA5 data 50 and contour level 20000
# 2019
# 3
# Opening ERA5 data 10 and contour level 30000
# Opening ERA5 data 50 and contour level 20000
# 2020
# 11
# Opening ERA5 data 10 and contour level 30000
# Opening ERA5 data 50 and contour level 20000
# 2020
# 12
# Opening ERA5 data 10 and contour level 30000
# Opening ERA5 data 50 and contour level 20000
# 2020
# 1
# Opening ERA5 data 10 and contour level 30000
# Opening ERA5 data 50 and contour level 20000
# 2020
# 2
# Opening ERA5 data 10 and contour level 30000
# Opening ERA5 data 50 and contour level 20000
# 2020
# 3
# Opening ERA5 data 10 and contour level 30000
# Opening ERA5 data 50 and contour level 20000
# 2021
# 11
# Opening ERA5 data 10 and contour level 30000
# Opening ERA5 data 50 and contour level 20000
# 2021
# 12
# Opening ERA5 data 10 and contour level 30000
# Opening ERA5 data 50 and contour level 20000
# 2021
# 1
# Opening ERA5 data 10 and contour level 30000
# Opening ERA5 data 50 and contour level 20000
# 2021
# 2
# Opening ERA5 data 10 and contour level 30000
# Opening ERA5 data 50 and contour level 20000
# 2021
# 3
# Opening ERA5 data 10 and contour level 30000
# Opening ERA5 data 50 and contour level 20000

# %%
##PICKLE OUT AND SAVE DATA
pickle.dump(ephi_ratio10, open("era5_ratio10_59.p", 'wb'))
pickle.dump(ephi_wind10, open("era5_wind10_59.p", 'wb')) 
pickle.dump(ephi_cenlat10, open("era5_cenlat10_59.p", 'wb'))
pickle.dump(ephi_cenlon10, open("era5_cenlon10_59.p", 'wb'))
pickle.dump(ephi_size10, open("era5_size10_59.p", 'wb'))
pickle.dump(ephi10, open("era5_ephi10_59.p", 'wb'))
pickle.dump(number10, open("era5_number10_59.p", 'wb'))

pickle.dump(ephi_ratio50, open("era5_ratio50_59.p", 'wb'))
pickle.dump(ephi_wind50, open("era5_wind50_59.p", 'wb')) 
pickle.dump(ephi_cenlat50, open("era5_cenlat50_59.p", 'wb'))
pickle.dump(ephi_cenlon50, open("era5_cenlon50_59.p", 'wb'))
pickle.dump(ephi_size50, open("era5_size50_59.p", 'wb'))
pickle.dump(ephi50, open("era5_ephi50_59.p", 'wb'))
pickle.dump(number50, open("era5_number50_59.p", 'wb'))

# %%
ephi50[59:]
# Out:
# array([[ 8.31520732e+01,  9.17433259e+01,  9.79707642e+01,
#          1.04246414e+02,  1.07395396e+02,  1.11322821e+02,
#          1.12357994e+02,  9.89207509e+01,  8.90149423e+01,
#          8.70984013e+01,  8.90306517e+01,  9.23967680e+01,
#          9.70652277e+01,  1.01086986e+02,  1.05874407e+02,
#          1.08334883e+02,  1.01288014e+02,  9.61433717e+01,
#          9.47616352e+01,  9.52733327e+01,  9.49100294e+01,
#          9.56536910e+01,  9.67074075e+01,  9.67361896e+01,
#          9.76242596e+01,  1.02912326e+02,  1.11198780e+02,
#          1.15312045e+02,  1.18973060e+02,  1.23988137e+02,
#          1.27626120e+02,  1.30306297e+02,  1.30542565e+02,
#          1.26634970e+02,  1.13893703e+02,  1.01763475e+02,
#          9.85713133e+01,  1.01458556e+02,  1.07432160e+02,
#          1.13400952e+02,  1.20025185e+02,  1.25677962e+02,
#          1.30831119e+02, -4.17560537e+01, -3.53392296e+01,
#         -3.34777261e+01, -3.57454635e+01, -4.03714317e+01,
#         -3.76193727e+01, -3.02821354e+01, -2.56025278e+01,
