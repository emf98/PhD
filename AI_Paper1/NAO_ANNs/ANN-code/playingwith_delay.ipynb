# %% [raw]
# !pip install netCDF4
# !pip install cmocean
# !pip install investigate

# %% [raw]
# from comet_ml import Experiment
# experiment = Experiment(
#   api_key="UzloboNe4UsDg9WE6plFnbWqW",
#   project_name="general",
#   workspace="emf98")

# %% [markdown]
# #### The first two cells here are for additional imports on starting a new file in NVIDIA + my comet tracking initalization if I wish to use it.

# %%
##import the python functions from my NN file when I have one created and relevant

##I am just going to throw that definition statement in later for the sake of editing

# %% [markdown]
# #### These next three chunks are just a bunch of import statements.

# %%
# %matplotlib inline
##so-called "math" related imports
from netCDF4 import Dataset as ncread
import numpy as np
from scipy.io import loadmat
import pandas as pd
import h5py
import math
from random import seed
from random import randint
from random import sample
from scipy.ndimage import gaussian_filter
from sklearn.metrics import brier_score_loss
import xarray as xr

import pickle

##plotting related imports
import matplotlib.pyplot as plt
from matplotlib import rcParams #For changing text properties
import cmocean #A package with beautiful colormaps
from cartopy import crs as ccrs #Useful for plotting maps
import cartopy.util #Requires separate import
from cartopy.util import add_cyclic_point
import cartopy.feature as cf
from cartopy.mpl.ticker import LongitudeFormatter, LatitudeFormatter
import matplotlib.path as mpath
import matplotlib.colors as mcolors
# Out:
# /tmp/ipykernel_2132886/3801934532.py:6: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
##import tensorflow/keras related files
import tensorflow as tf    
#tf.compat.v1.disable_v2_behavior() # <-- HERE !

from tensorflow import keras
from tensorflow.keras import layers, models
from tensorflow.keras import Input
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras import regularizers
import tensorflow.keras.backend as K
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Dropout, Activation, Reshape, Flatten, LSTM, Dense, Dropout, Embedding, Bidirectional, GRU
from tensorflow.keras import Sequential
from tensorflow.keras import initializers, regularizers
from tensorflow.keras import optimizers
from tensorflow.keras import constraints
from tensorflow.keras.layers import Layer, InputSpec
from tensorflow.keras.callbacks import EarlyStopping
# Out:
# 2024-11-19 14:29:49.328490: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-19 14:29:49.328558: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-19 14:29:49.328604: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-19 14:29:49.335477: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
tf.compat.v1.disable_eager_execution()
import innvestigate
import investigate

# %%
from climoprobs import climo

# %% [markdown]
# #### Upload data.

# %%
#inputs
infile = open("./data/ANN/1118_filtered_gph.p", 'rb') 
input = pickle.load(infile)
infile.close()

#outputs
infile = open("./data/ANN/1118_class_filt.p", 'rb')
temp = pickle.load(infile)
infile.close()
#temp = temp.flatten()

#climo
#infile = open("./data/ANN/eur_climoprob_filt.p", 'rb')
#climo = pickle.load(infile)
#infile.close()
#temp = temp.flatten()

# %%
##input shape (samples, lat, lon), these will be different from the output
input.shape
# Out:
# (63, 151, 21, 37)

# %%
temp = temp.reshape(63,151)

# %%
temp_n = np.zeros((63,149))
input_n = np.zeros((63,149,21,37))

for i in range(63):
    for j in range(149):
        temp_n[i,j] = temp[i,j+2]
        input_n[i,j] = input[i,j,:,:]

# %%
##output shape (samples, lat, lon), these will be different from the input
temp_n.shape
# Out:
# (63, 149)

# %%
##Set X_all and Y_all datasets
X_all = np.copy(input_n.reshape(9387,777))
Y_all = np.copy(temp_n.reshape(9387))

##training data partition out
X_tri = X_all[:8791,:]
Y_tri = Y_all[:8791]

#testing data partition out
X_tes = X_all[8791:,:]
Y_tes = Y_all[8791:]

#Convert the Y array into a categorical array. This means we will create one-hot vector labels for all of the inputs.
# The one-hot vectors have an index for each possible output category (two in our case)
# A "1" is put in the index corresponding to the category to which the sample belongs
Y_all = keras.utils.to_categorical(Y_all)
Y_tri = keras.utils.to_categorical(Y_tri)
Y_tes= keras.utils.to_categorical(Y_tes)

# %%
##checking my data for NaN of Infs because I need to make sure this doesn't cause
#the model to throw back no loss

if np.any(np.isnan(X_all)) or np.any(np.isinf(X_all)):
    print("NaN or Inf values found in X_all!")

if np.any(np.isnan(Y_all)) or np.any(np.isinf(Y_all)):
    print("NaN or Inf values found in Y_all!")

# %% [markdown]
# ### Begin establishing specifics of model.

# %%
##set 6 years of data for validation
frac_ind = 894
frac_ind
# Out:
# 894

# %%
##checking to make sure shape was properly one hot encoded
Y_all.shape
# Out:
# (9387, 2)

# %%
##class weight creator for the instance where now I have a four dimensional output array 
def class_weight_creator(Y):
    class_dict = {}
    Y_reshaped = Y.reshape(-1, Y.shape[-1])
    weights = np.max(np.sum(Y_reshaped, axis=0)) / np.sum(Y_reshaped, axis=0)
    for i in range(Y.shape[-1] ):
        class_dict[i] = weights[i]
        
    return class_dict

# %%
##number of input nodes
numb_int = X_all.shape[-1]

##fraction of training data
X_validation = X_tri[0:frac_ind]
Y_validation = Y_tri[0:frac_ind]
        
X_train = X_tri[frac_ind:len(X_tri)]
Y_train = Y_tri[frac_ind:len(Y_tri)]

X_test = X_tes
Y_test = Y_tes

# %%
Y_train.shape
# Out:
# (7897, 2)

# %%
numb_int
# Out:
# 777

# %%
##do the class_dict weights
class_weight = class_weight_creator(Y_train)
class_weight
# Out:
# {0: 1.0543704, 1: 1.0}

# %% [markdown]
# ### Model Arcitecture.

# %%
def basic_ANN(number_inputs,num_cats,n1,n2,rl1,rl2,learn,epochs):
    
    input_tensor = Input(shape=(int(number_inputs),))
    
    layer1 = layers.Dense(n1, activation='relu', use_bias=True,
                          kernel_initializer='he_normal',bias_initializer='he_normal',
                          kernel_regularizer=keras.regularizers.l2(l2= rl1))(input_tensor)
    
    layer1 = layers.Dense(n2, activation='relu',use_bias=True,
                          kernel_initializer='he_normal',bias_initializer='he_normal',
                          kernel_regularizer=keras.regularizers.l2(l2=rl2))(layer1)

    #decay_rate = learn / epochs
    output_tensor = layers.Dense(num_cats,activation='softmax')(layer1)
    model = Model(input_tensor, output_tensor)
    model.compile(optimizer=keras.optimizers.legacy.Adam(learning_rate=learn),
              loss = 'categorical_crossentropy', #Our loss function is based on categorical error
              metrics=[keras.metrics.categorical_accuracy], #We will print out the categorical accuracy as the network is trained
              )
    return model

# %%
######
batch_size = 256 #The number of samples the network sees before it backpropagates (batch size)
epochs = 50 #The number of times the network will loop through the entire dataset (epochs)
shuffle = True #Set whether to shuffle the training data so the model doesn't see it sequentially 
verbose = 2 #Set whether the model will output information when trained (0 = no output; 2 = output accuracy every epoch)

# %%
Y_validation.shape
# Out:
# (894, 2)

# %%
##create model.
#model = basic_ANN(numb_int, 2, 128, 8, 0.065, 0.05, 0.00068, epochs)

#model = basic_ANN(numb_int, 2, 128, 8, 0.078, 0.07, 0.0013, epochs)
#model = basic_ANN(numb_int, 2, 128, 8, 0.078, 0.07, 0.002, epochs)
#model = basic_ANN(numb_int, 2, 128, 4, 0.012, 0.00064, 0.015, epochs)
#model = basic_ANN(numb_int, 2, 128, 12, 0.6, 1, 0.0075, epochs)

##most recent playing, model = basic_ANN(numb_int, 2, 128, 8, 0.7454, 0.769, 0.0024, epochs)

model = basic_ANN(numb_int, 2, 128, 4, 0.38, 0.64, 0.001, epochs)

early_stopping = EarlyStopping(monitor='val_loss',patience=4,restore_best_weights=True,verbose=1)

# %%
model.fit(X_train, Y_train, validation_data=(X_validation, Y_validation),
          batch_size=batch_size, epochs=epochs, shuffle=shuffle,class_weight = class_weight, callbacks=[early_stopping])
# Out:
# Train on 7897 samples, validate on 894 samples
# Epoch 1/50
# 7897/7897 [==============================] - 0s 21us/sample - loss: 96.5305 - categorical_accuracy: 0.5313 - val_loss: 79.3254 - val_categorical_accuracy: 0.4866
# Epoch 2/50
#  256/7897 [..............................] - ETA: 0s - loss: 79.3224 - categorical_accuracy: 0.5469
# 2024-11-19 14:56:03.492405: W tensorflow/c/c_api.cc:305] Operation '{name:'training/Adam/dense_2/kernel/v/Assign' id:399 op device:{requested: '', assigned: ''} def:{{{node training/Adam/dense_2/kernel/v/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](training/Adam/dense_2/kernel/v, training/Adam/dense_2/kernel/v/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training_v1.py:2335: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates = self.state_updates
# 7897/7897 [==============================] - 0s 10us/sample - loss: 65.9707 - categorical_accuracy: 0.5140 - val_loss: 52.7906 - val_categorical_accuracy: 0.4843
# Epoch 3/50
# 7897/7897 [==============================] - 0s 10us/sample - loss: 43.2469 - categorical_accuracy: 0.5136 - val_loss: 34.3023 - val_categorical_accuracy: 0.4821
# Epoch 4/50
# 7897/7897 [==============================] - 0s 10us/sample - loss: 28.1940 - categorical_accuracy: 0.5135 - val_loss: 22.5273 - val_categorical_accuracy: 0.4866
# Epoch 5/50
# 7897/7897 [==============================] - 0s 10us/sample - loss: 18.7280 - categorical_accuracy: 0.5030 - val_loss: 15.1894 - val_categorical_accuracy: 0.5313
# Epoch 6/50
# 7897/7897 [==============================] - 0s 10us/sample - loss: 12.8211 - categorical_accuracy: 0.4988 - val_loss: 10.6941 - val_categorical_accuracy: 0.5257
# Epoch 7/50
# 7897/7897 [==============================] - 0s 10us/sample - loss: 9.1413 - categorical_accuracy: 0.5008 - val_loss: 7.7339 - val_categorical_accuracy: 0.4911
# Epoch 8/50
# 7897/7897 [==============================] - 0s 10us/sample - loss: 6.8480 - categorical_accuracy: 0.5117 - val_loss: 6.0381 - val_categorical_accuracy: 0.5582
# Epoch 9/50
# 7897/7897 [==============================] - 0s 11us/sample - loss: 5.2321 - categorical_accuracy: 0.5538 - val_loss: 4.5877 - val_categorical_accuracy: 0.6253
# Epoch 10/50
# 7897/7897 [==============================] - 0s 11us/sample - loss: 4.1043 - categorical_accuracy: 0.5944 - val_loss: 3.6284 - val_categorical_accuracy: 0.6577
# Epoch 11/50
# 7897/7897 [==============================] - 0s 11us/sample - loss: 3.3137 - categorical_accuracy: 0.5981 - val_loss: 2.9921 - val_categorical_accuracy: 0.6711
# Epoch 12/50
# 7897/7897 [==============================] - 0s 10us/sample - loss: 2.7090 - categorical_accuracy: 0.6339 - val_loss: 2.4320 - val_categorical_accuracy: 0.6544
# Epoch 13/50
# 7897/7897 [==============================] - 0s 10us/sample - loss: 2.2632 - categorical_accuracy: 0.6532 - val_loss: 2.0912 - val_categorical_accuracy: 0.6521
# Epoch 14/50
# 7897/7897 [==============================] - 0s 10us/sample - loss: 2.0026 - categorical_accuracy: 0.6587 - val_loss: 1.9461 - val_categorical_accuracy: 0.6779
# Epoch 15/50
# 7897/7897 [==============================] - 0s 11us/sample - loss: 1.8054 - categorical_accuracy: 0.6591 - val_loss: 1.6731 - val_categorical_accuracy: 0.6510
# Epoch 16/50
# 7897/7897 [==============================] - 0s 10us/sample - loss: 1.5309 - categorical_accuracy: 0.6657 - val_loss: 1.4293 - val_categorical_accuracy: 0.6600
# Epoch 17/50
# 7897/7897 [==============================] - 0s 10us/sample - loss: 1.3384 - categorical_accuracy: 0.6696 - val_loss: 1.2613 - val_categorical_accuracy: 0.6566
# Epoch 18/50
# 7897/7897 [==============================] - 0s 11us/sample - loss: 1.2123 - categorical_accuracy: 0.6685 - val_loss: 1.1658 - val_categorical_accuracy: 0.6488
# Epoch 19/50
# 7897/7897 [==============================] - 0s 11us/sample - loss: 1.2919 - categorical_accuracy: 0.6686 - val_loss: 1.4127 - val_categorical_accuracy: 0.6342
# Epoch 20/50
# 7897/7897 [==============================] - 0s 11us/sample - loss: 2.0025 - categorical_accuracy: 0.6443 - val_loss: 1.9854 - val_categorical_accuracy: 0.6465
# Epoch 21/50
# 7897/7897 [==============================] - 0s 10us/sample - loss: 1.6242 - categorical_accuracy: 0.6599 - val_loss: 1.3242 - val_categorical_accuracy: 0.6309
# Epoch 22/50
# 7897/7897 [==============================] - 0s 11us/sample - loss: 1.1833 - categorical_accuracy: 0.6622 - val_loss: 1.0617 - val_categorical_accuracy: 0.6376
# Epoch 23/50
# 7897/7897 [==============================] - 0s 11us/sample - loss: 0.9984 - categorical_accuracy: 0.6694 - val_loss: 0.9363 - val_categorical_accuracy: 0.6488
# Epoch 24/50
# 7897/7897 [==============================] - 0s 11us/sample - loss: 0.9077 - categorical_accuracy: 0.6694 - val_loss: 0.8765 - val_categorical_accuracy: 0.6465
# Epoch 25/50
# 7897/7897 [==============================] - 0s 11us/sample - loss: 0.8589 - categorical_accuracy: 0.6720 - val_loss: 0.8436 - val_categorical_accuracy: 0.6488
# Epoch 26/50
# 7897/7897 [==============================] - 0s 10us/sample - loss: 0.8316 - categorical_accuracy: 0.6744 - val_loss: 0.8827 - val_categorical_accuracy: 0.6600
# Epoch 27/50
# 7897/7897 [==============================] - 0s 11us/sample - loss: 0.8286 - categorical_accuracy: 0.6713 - val_loss: 0.8148 - val_categorical_accuracy: 0.6365
# Epoch 28/50
# 7897/7897 [==============================] - 0s 11us/sample - loss: 0.7996 - categorical_accuracy: 0.6706 - val_loss: 0.7750 - val_categorical_accuracy: 0.6443
# Epoch 29/50
# 7897/7897 [==============================] - 0s 11us/sample - loss: 0.7719 - categorical_accuracy: 0.6710 - val_loss: 0.7514 - val_categorical_accuracy: 0.6409
# Epoch 30/50
# 7897/7897 [==============================] - 0s 10us/sample - loss: 0.7497 - categorical_accuracy: 0.6710 - val_loss: 0.7424 - val_categorical_accuracy: 0.6465
# Epoch 31/50
# 7897/7897 [==============================] - 0s 10us/sample - loss: 0.7295 - categorical_accuracy: 0.6729 - val_loss: 0.7062 - val_categorical_accuracy: 0.6667
# Epoch 32/50
# 7897/7897 [==============================] - 0s 10us/sample - loss: 0.7249 - categorical_accuracy: 0.6744 - val_loss: 0.7150 - val_categorical_accuracy: 0.6600
# Epoch 33/50
# 7897/7897 [==============================] - 0s 10us/sample - loss: 0.7294 - categorical_accuracy: 0.6708 - val_loss: 0.7366 - val_categorical_accuracy: 0.6477
# Epoch 34/50
# 7897/7897 [==============================] - 0s 11us/sample - loss: 0.7110 - categorical_accuracy: 0.6718 - val_loss: 0.6961 - val_categorical_accuracy: 0.6398
# Epoch 35/50
# 7897/7897 [==============================] - 0s 10us/sample - loss: 0.7023 - categorical_accuracy: 0.6741 - val_loss: 0.6880 - val_categorical_accuracy: 0.6655
# Epoch 36/50
# 7897/7897 [==============================] - 0s 11us/sample - loss: 0.7139 - categorical_accuracy: 0.6689 - val_loss: 0.7062 - val_categorical_accuracy: 0.6510
# Epoch 37/50
# 7897/7897 [==============================] - 0s 10us/sample - loss: 0.7012 - categorical_accuracy: 0.6738 - val_loss: 0.6836 - val_categorical_accuracy: 0.6532
# Epoch 38/50
# 7897/7897 [==============================] - 0s 11us/sample - loss: 0.6876 - categorical_accuracy: 0.6754 - val_loss: 0.6680 - val_categorical_accuracy: 0.6544
# Epoch 39/50
# 7897/7897 [==============================] - 0s 11us/sample - loss: 0.6795 - categorical_accuracy: 0.6718 - val_loss: 0.6604 - val_categorical_accuracy: 0.6566
# Epoch 40/50
# 7897/7897 [==============================] - 0s 10us/sample - loss: 0.6697 - categorical_accuracy: 0.6752 - val_loss: 0.6471 - val_categorical_accuracy: 0.6723
# Epoch 41/50
# 7897/7897 [==============================] - 0s 10us/sample - loss: 0.6674 - categorical_accuracy: 0.6757 - val_loss: 0.6465 - val_categorical_accuracy: 0.6734
# Epoch 42/50
# 7897/7897 [==============================] - 0s 10us/sample - loss: 0.6619 - categorical_accuracy: 0.6751 - val_loss: 0.6462 - val_categorical_accuracy: 0.6655
# Epoch 43/50
# 7897/7897 [==============================] - 0s 10us/sample - loss: 0.6605 - categorical_accuracy: 0.6741 - val_loss: 0.6389 - val_categorical_accuracy: 0.6622
# Epoch 44/50
# 7897/7897 [==============================] - 0s 10us/sample - loss: 0.6565 - categorical_accuracy: 0.6751 - val_loss: 0.6397 - val_categorical_accuracy: 0.6600
# Epoch 45/50
# 7897/7897 [==============================] - 0s 10us/sample - loss: 0.6545 - categorical_accuracy: 0.6732 - val_loss: 0.6424 - val_categorical_accuracy: 0.6544
# Epoch 46/50
# 7897/7897 [==============================] - 0s 10us/sample - loss: 0.6551 - categorical_accuracy: 0.6710 - val_loss: 0.6432 - val_categorical_accuracy: 0.6499
# Epoch 47/50
# 5632/7897 [====================>.........] - ETA: 0s - loss: 0.6468 - categorical_accuracy: 0.6767Restoring model weights from the end of the best epoch: 43.
# 7897/7897 [==============================] - 0s 13us/sample - loss: 0.6523 - categorical_accuracy: 0.6730 - val_loss: 0.6400 - val_categorical_accuracy: 0.6577
# Epoch 47: early stopping

# %%
train_loss=model.history.history['loss']
val_loss=model.history.history['val_loss']
    
cat_acc=model.history.history['categorical_accuracy']
val_acc=model.history.history['val_categorical_accuracy']
        
pred = model.predict(X_all)
pred_val = model.predict(X_validation)
pred_train = model.predict(X_train)
pred_test = model.predict(X_test)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training_v1.py:2359: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# 2024-11-19 14:56:07.533962: W tensorflow/c/c_api.cc:305] Operation '{name:'dense_2/Softmax' id:90 op device:{requested: '', assigned: ''} def:{{{node dense_2/Softmax}} = Softmax[T=DT_FLOAT, _has_manual_control_dependencies=true](dense_2/BiasAdd)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.

# %%
# Look at the optimization history
fig, (ax1,ax2) = plt.subplots(1,2, figsize=plt.figaspect(0.25))
ax1.plot(train_loss, label='Training loss')
ax1.plot(val_loss, label='Validation loss')
ax1.set_yscale('log')
ax1.set_title('loss')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('loss')
ax1.legend()

ax2.plot(cat_acc, label='Training ACC')
ax2.plot(val_acc, label='Validation ACC')
ax2.set_title('Accuracy')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Acc')
ax2.legend
# Out:
# <bound method Axes.legend of <Axes: title={'center': 'Accuracy'}, xlabel='Epoch', ylabel='Acc'>>

# %%
##calculate climatologies

climo_full = climo(Y_all,63,149)
climo_train = climo(Y_train,53,149)
climo_val = climo(Y_validation,6,149)
climo_test = climo(Y_test,4,149)

# %%
#from google gemini, thanks google
def calculate_accuracy(y_true, y_prob, threshold=0.5):
    """
    Calculates accuracy given true labels and predicted probabilities.
    Args:
        y_true: Array of true labels (e.g., [0, 1, 1, 0]).
        y_prob: Array of predicted probabilities (e.g., [0.3, 0.7, 0.9, 0.2]).
        threshold: Threshold to convert probabilities to binary predictions.
    Returns:
        Accuracy score (float).
    """

    y_pred = (y_prob >= threshold).astype(int)
    return np.mean(y_true == y_pred)

# %%
q90 = np.percentile(pred_train,90,axis=0)
q90
# Out:
# array([0.78283769, 0.73506823])

# %%
great90 = [i for i, row in enumerate(pred_train)
           if any(pred_train > q90[i] for i, pred_train in enumerate(row))]

# Create the arrays of probabilities and actual values that exceed the 90th percentile
test90 = pred_train[great90]
test90_norm = Y_train[great90]

print(len(test90))
print(len(test90_norm))
# Out:
# 1580
# 1580

# %%
acc = calculate_accuracy(test90_norm, test90, threshold=0.5)
acc
# Out:
# 0.8455696202531645

# %%
for j in range(len(climo_full[0,:])):
    bs = brier_score_loss(Y_all[:,j], pred[:,j])
    bs_ref = brier_score_loss(Y_all[:,j], climo_full[:,j])
    bss = 1 - (bs / bs_ref)

# %%
import sklearn
pred_class = []
for k in range(len(Y_all[:,0])):##PREDICTIVE
    #print(pred_val[k,0])
    #print(pred_val[k,1])
    #print(pred_val[k,2])
    if pred[k,0] > pred[k,1]:
        #print("a")
        pred_class.append([1.,0.])
    elif pred[k,1] > pred[k,0]:
        #print("b")
        pred_class.append([0.,1.])
prd = np.asarray(pred_class)
for j in range(len(climo_full[0,:])):
    recal = sklearn.metrics.recall_score(Y_all[:,j], prd[:,j])

# %%
pred_class = []
for k in range(len(Y_all[:,0])):##PREDICTIVE
    #print(pred_val[k,0])
    #print(pred_val[k,1])
    #print(pred_val[k,2])
    if pred[k,0] > pred[k,1]:
        #print("a")
        pred_class.append([1.,0.])
    elif pred[k,1] > pred[k,0]:
        #print("b")
        pred_class.append([0.,1.])
prd = np.asarray(pred_class)
for j in range(len(climo_full[0,:])):
    prec = sklearn.metrics.precision_score(Y_all[:,j], prd[:,j])

# %%
print("Brier Skill Score: ",bss)
print("Recall Accuracy Score: ",recal)
print("Precision Accuracy Score: ",prec)
# Out:
# Brier Skill Score:  0.11893853117669428
# Recall Accuracy Score:  0.7211196991852935
# Precision Accuracy Score:  0.6572734196496572

# %%
# Creating an analyzer
model_wo_sm = innvestigate.model_wo_softmax(model)
gradient_analyzer = innvestigate.create_analyzer("deep_taylor", model_wo_sm)

# %%
# Applying the analyzer
analysis = gradient_analyzer.analyze(X_train)
# Out:
# 2024-11-19 17:29:27.269206: W tensorflow/c/c_api.cc:305] Operation '{name:'kernel_2/Assign' id:626 op device:{requested: '', assigned: ''} def:{{{node kernel_2/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](kernel_2, kernel_2/Initializer/stateless_truncated_normal)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-11-19 17:29:27.299490: W tensorflow/c/c_api.cc:305] Operation '{name:'gradients/MaxNeuronSelection/Max_grad/range' id:714 op device:{requested: '', assigned: ''} def:{{{node gradients/MaxNeuronSelection/Max_grad/range}} = Range[Tidx=DT_INT32, _class=["loc:@MaxNeuronSelection/Max"], _has_manual_control_dependencies=true](gradients/MaxNeuronSelection/Max_grad/range/start, gradients/MaxNeuronSelection/Max_grad/Size, gradients/MaxNeuronSelection/Max_grad/range/delta)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-11-19 17:29:27.309201: W tensorflow/c/c_api.cc:305] Operation '{name:'gradients/MaxNeuronSelection/Max_grad/mod' id:710 op device:{requested: '', assigned: ''} def:{{{node gradients/MaxNeuronSelection/Max_grad/mod}} = FloorMod[T=DT_INT32, _class=["loc:@MaxNeuronSelection/Max"], _has_manual_control_dependencies=true](gradients/MaxNeuronSelection/Max_grad/add, gradients/MaxNeuronSelection/Max_grad/Size)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-11-19 17:29:27.318896: W tensorflow/c/c_api.cc:305] Operation '{name:'gradients/MaxNeuronSelection/Max_grad/ones' id:716 op device:{requested: '', assigned: ''} def:{{{node gradients/MaxNeuronSelection/Max_grad/ones}} = Fill[T=DT_INT32, _class=["loc:@MaxNeuronSelection/Max"], _has_manual_control_dependencies=true, index_type=DT_INT32](gradients/MaxNeuronSelection/Max_grad/Shape_1, gradients/MaxNeuronSelection/Max_grad/ones/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-11-19 17:29:27.333132: W tensorflow/c/c_api.cc:305] Operation '{name:'MaxNeuronSelection/Max/reduction_indices' id:588 op device:{requested: '', assigned: ''} def:{{{node MaxNeuronSelection/Max/reduction_indices}} = Const[_has_manual_control_dependencies=true, dtype=DT_INT32, value=Tensor<type: int32 shape: [] values: -1>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-11-19 17:29:27.348933: W tensorflow/c/c_api.cc:305] Operation '{name:'mul_6/x' id:743 op device:{requested: '', assigned: ''} def:{{{node mul_6/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-11-19 17:29:27.358643: W tensorflow/c/c_api.cc:305] Operation '{name:'Const_1' id:740 op device:{requested: '', assigned: ''} def:{{{node Const_1}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-11-19 17:29:27.374005: W tensorflow/c/c_api.cc:305] Operation '{name:'mul_5' id:677 op device:{requested: '', assigned: ''} def:{{{node mul_5}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_19, Cast_5)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-11-19 17:29:27.403839: W tensorflow/c/c_api.cc:305] Operation '{name:'mul_2' id:633 op device:{requested: '', assigned: ''} def:{{{node mul_2}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_13, Cast_2)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-11-19 17:29:27.415680: W tensorflow/c/c_api.cc:305] Operation '{name:'mul_7/x' id:787 op device:{requested: '', assigned: ''} def:{{{node mul_7/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-11-19 17:29:27.425622: W tensorflow/c/c_api.cc:305] Operation '{name:'Const_2' id:784 op device:{requested: '', assigned: ''} def:{{{node Const_2}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-11-19 17:29:27.441093: W tensorflow/c/c_api.cc:305] Operation '{name:'mul_3' id:639 op device:{requested: '', assigned: ''} def:{{{node mul_3}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_15, Cast_3)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-11-19 17:29:27.472616: W tensorflow/c/c_api.cc:305] Operation '{name:'mul' id:595 op device:{requested: '', assigned: ''} def:{{{node mul}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_9, Cast)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-11-19 17:29:27.485129: W tensorflow/c/c_api.cc:305] Operation '{name:'mul_8/x' id:818 op device:{requested: '', assigned: ''} def:{{{node mul_8/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-11-19 17:29:27.831671: W tensorflow/c/c_api.cc:305] Operation '{name:'Const_3' id:815 op device:{requested: '', assigned: ''} def:{{{node Const_3}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-11-19 17:29:27.851445: W tensorflow/c/c_api.cc:305] Operation '{name:'mul_1' id:601 op device:{requested: '', assigned: ''} def:{{{node mul_1}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_11, Cast_1)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.

# %%
Y_train[0]
# Out:
# array([0., 1.], dtype=float32)

# %%
positive = []
negative = []
for i in range(len(X_train[:,0])):
    input = np.empty((1,777))
    input[0,:] = X_train[i,:]
    #print(input.shape)
    if Y_train[i,0] == 0:
        positive.append(gradient_analyzer.analyze(input))
    elif Y_train[i,0] == 1:
        negative.append(gradient_analyzer.analyze(input))

# %%
len(negative)
# Out:
# 3844

# %%
pos = np.array(positive)
pos.reshape((4053,777))
#Convert the list to an array to make processing simpler and reshape it into a 2-D map (our inputs were vectorized)
posLRP_heatmaps = pos.reshape(pos.shape[0], 21, 37)
posLRP_heatmaps_scaled = posLRP_heatmaps/np.nanmax(posLRP_heatmaps, axis=(-2,-1))[:,np.newaxis,np.newaxis]
posLRP_heatmaps_mean = np.nanmean(posLRP_heatmaps_scaled, axis=0)

neg = np.array(negative)
neg.reshape((3844,777))
negLRP_heatmaps = neg.reshape(neg.shape[0], 21, 37)
negLRP_heatmaps_scaled = negLRP_heatmaps/np.nanmax(negLRP_heatmaps, axis=(-2,-1))[:,np.newaxis,np.newaxis]
negLRP_heatmaps_mean = np.nanmean(negLRP_heatmaps_scaled, axis=0)

#lat
lats = np.arange(80, 29.5, -2.5)
#lon
lons = np.arange(-100, -9.5, 2.5)
###########################################################################################################
# plot the original data 
color = 'BuGn' 
colorbarMin = 0
colorbarMax = 1
colorspace = 0.05
level = np.arange(colorbarMin,colorbarMax+colorspace,colorspace)
ax = plt.axes(projection=ccrs.cartopy.crs.PlateCarree(central_longitude=180))
h = ax.contourf(lons, lats, negLRP_heatmaps_mean, level, transform=ccrs.PlateCarree(), cmap=color,extend='both')
#plt.contourf(lons, lats, LRP_heatmaps_mean, level, cmap=color,extend='both')
cbar = plt.colorbar(h, orientation='horizontal', shrink=1,fraction=0.1,pad=0.1,aspect=35)
cbar.ax.tick_params(labelsize=10) 
#Add in the coordinate system:
long = np.arange(-100, -10, 5)
latg = np.arange(80, 30 ,-5)
ax.set_xticks(long, crs=ccrs.PlateCarree());
ax.set_yticks(latg, crs=ccrs.PlateCarree());
ax.set_xticklabels(long,fontsize=8)
ax.set_yticklabels(latg,fontsize=8)
ax.set_ylabel('Latitude',fontsize=10);
ax.set_xlabel('Longitude',fontsize=10);

#Add in the continents
#define the coastlines, the color (#000000) and the resolution (110m) 
feature1 = cf.NaturalEarthFeature(
    name='coastline', category='physical',
    scale='110m',
    edgecolor='#000000', facecolor='none')

ax.add_feature(feature1)

plt.tight_layout()
#Set a title for your map:
title = 'LRP on 500hPa GPH associated with Negative Temp Anomalies over Europe'
plt.title(title,fontsize=10, y=1.03)
#plt.savefig("LRP_take1.png")
# Out:
# /tmp/ipykernel_2132886/1775367411.py:5: RuntimeWarning: invalid value encountered in divide
#   posLRP_heatmaps_scaled = posLRP_heatmaps/np.nanmax(posLRP_heatmaps, axis=(-2,-1))[:,np.newaxis,np.newaxis]
# /tmp/ipykernel_2132886/1775367411.py:11: RuntimeWarning: invalid value encountered in divide
#   negLRP_heatmaps_scaled = negLRP_heatmaps/np.nanmax(negLRP_heatmaps, axis=(-2,-1))[:,np.newaxis,np.newaxis]
# Text(0.5, 1.03, 'LRP on 500hPa GPH associated with Negative Temp Anomalies over Europe')

# %%
tf.keras.backend.clear_session()

# %%
#analysis.shape
# Out:
# (7897, 777)

# %%
#Convert the list to an array to make processing simpler and reshape it into a 2-D map (our inputs were vectorized)
LRP_heatmaps = analysis.reshape(analysis.shape[0], 21, 37)

#Normalize each heatmap to have a maximum value of 1 so all samples can be compared equally
LRP_heatmaps_scaled = LRP_heatmaps/np.nanmax(LRP_heatmaps, axis=(-2,-1))[:,np.newaxis,np.newaxis]

#Now take the mean across all samples to make a composite...
LRP_heatmaps_mean = np.nanmean(LRP_heatmaps_scaled, axis=0)
# Out:
# /tmp/ipykernel_2132886/2154470865.py:5: RuntimeWarning: invalid value encountered in divide
#   LRP_heatmaps_scaled = LRP_heatmaps/np.nanmax(LRP_heatmaps, axis=(-2,-1))[:,np.newaxis,np.newaxis]

# %%
LRP_heatmaps_mean.shape
# Out:
# (21, 37)

# %%
#lat
lats = np.arange(80, 29.5, -2.5)
#lon
lons = np.arange(-100, -9.5, 2.5)

# %%
# plot the original data 
color = 'BuGn' 
colorbarMin = 0
colorbarMax = 1
colorspace = 0.05
level = np.arange(colorbarMin,colorbarMax+colorspace,colorspace)
ax = plt.axes(projection=ccrs.cartopy.crs.PlateCarree(central_longitude=180))
h = ax.contourf(lons, lats, LRP_heatmaps_mean, level, transform=ccrs.PlateCarree(), cmap=color,extend='both')
#plt.contourf(lons, lats, LRP_heatmaps_mean, level, cmap=color,extend='both')
cbar = plt.colorbar(h, orientation='horizontal', shrink=1,fraction=0.1,pad=0.1,aspect=35)
cbar.ax.tick_params(labelsize=10) 
#Add in the coordinate system:
long = np.arange(-100, -10, 5)
latg = np.arange(80, 30 ,-5)
ax.set_xticks(long, crs=ccrs.PlateCarree());
ax.set_yticks(latg, crs=ccrs.PlateCarree());
ax.set_xticklabels(long,fontsize=8)
ax.set_yticklabels(latg,fontsize=8)
ax.set_ylabel('Latitude',fontsize=10);
ax.set_xlabel('Longitude',fontsize=10);

#Add in the continents
#define the coastlines, the color (#000000) and the resolution (110m) 
feature1 = cf.NaturalEarthFeature(
    name='coastline', category='physical',
    scale='110m',
    edgecolor='#000000', facecolor='none')

ax.add_feature(feature1)

plt.tight_layout()
#Set a title for your map:
title = 'LRP on 500hPa GPH associated with Temp Anomalies over Europe'
plt.title(title,fontsize=10, y=1.03)
#plt.savefig("LRP_take1.png")
# Out:
# Text(0.5, 1.03, 'LRP on 500hPa GPH associated with Temp Anomalies over Europe')
